# %%
import plado
from plado.parser import parse, parse_and_normalize
domain, problem = parse("data/stochastic/yahtzee/domain.pddl", "data/stochastic/yahtzee/1.pddl")
# domain, problem = parse("data/deterministic/blocksworld/domain.pddl", "data/deterministic/blocksworld/1.pddl")
# alternatively, with performing additional normalization steps
# domain, problem = parse_and_normalize(PATH_TO_DOMAIN, PATH_TO_PROBLEM)
# Out:
# ---------------------------------------------------------------------------
# UnexpectedToken                           Traceback (most recent call last)
# Cell In[1], line 3
#       1 import plado
#       2 from plado.parser import parse, parse_and_normalize
# ----> 3 domain, problem = parse("data/stochastic/yahtzee/domain.pddl", "data/stochastic/yahtzee/1.pddl")
#       4 # domain, problem = parse("data/deterministic/blocksworld/domain.pddl", "data/deterministic/blocksworld/1.pddl")
#       5 # alternatively, with performing additional normalization steps
#       6 # domain, problem = parse_and_normalize(PATH_TO_DOMAIN, PATH_TO_PROBLEM)
#
# File ~/.conda/envs/cs560/lib/python3.13/site-packages/plado/parser/__init__.py:12, in parse(domain_path, problem_path, skip_checks)
#       8 def parse(
#       9     domain_path: str, problem_path: str, skip_checks: bool = False
#      10 ) -> tuple[pddl.Domain, pddl.Problem]:
#      11     with open(domain_path, encoding="utf-8") as f:
# ---> 12         domain = parse_domain(LookaheadStreamer(tokenize(f.read())))
#      13     with open(problem_path, encoding="utf-8") as f:
#      14         problem = parse_problem(LookaheadStreamer(tokenize(f.read())))
#
# File ~/.conda/envs/cs560/lib/python3.13/site-packages/plado/parser/parser.py:478, in parse_domain(tokens)
#     476     derived_predicates.append(parse_derived_predicate(tokens))
#     477 elif tok.cat == Category.ACTION:
# --> 478     actions.append(parse_action(tokens))
#     479 else:
#     480     raise UnexpectedToken(tok, "Could not parse domain")
#
# File ~/.conda/envs/cs560/lib/python3.13/site-packages/plado/parser/parser.py:404, in parse_action(tokens)
#     402     if precondition is not None:
#     403         raise ParseError(f"Multiply defined :precondition at {tok}")
# --> 404     precondition = _parse_condition(tokens)
#     405 elif tok.cat == Category.EFFECT:
#     406     if effect is not None:
#
# File ~/.conda/envs/cs560/lib/python3.13/site-packages/plado/parser/parser.py:305, in _parse_condition(tokens)
#     303     next(tokens)
#     304     return pddl.Truth()
# --> 305 return _parse_formula(tokens)
#
# File ~/.conda/envs/cs560/lib/python3.13/site-packages/plado/parser/parser.py:256, in _parse_formula(tokens)
#     254         return pddl.Equals(lhs, rhs)
#     255 if tok.cat == Category.NOT:
# --> 256     _parse_open(tokens)
#     257     sub_formula = _parse_formula(tokens)
#     258     _parse_close(tokens)
#
# File ~/.conda/envs/cs560/lib/python3.13/site-packages/plado/parser/parser.py:183, in _parse_open(tokens)
#     181 tok = next(tokens)
#     182 if tok.cat != Category.LBRACK:
# --> 183     raise UnexpectedToken(tok, "Expected '('")
#
# UnexpectedToken: Received unexpected token <Token <Category.NAME: 5> 'rolled' @17:26>. Expected '('

# %%
domain.__dict__
# Out:
# {'name': 'blocks',
#  'requirements': [':strips', ':typing'],
#  'types': (<plado.pddl.type.Type at 0x784203cafe00>,),
#  'constants': (),
#  'predicates': (<plado.pddl.boolean_expression.Predicate at 0x784203caf0e0>,
#   <plado.pddl.boolean_expression.Predicate at 0x784203d2fed0>,
#   <plado.pddl.boolean_expression.Predicate at 0x78420335c050>,
#   <plado.pddl.boolean_expression.Predicate at 0x7842033542b0>,
#   <plado.pddl.boolean_expression.Predicate at 0x7842033543e0>),
#  'functions': (),
#  'actions': (<plado.pddl.action.Action at 0x784203358ad0>,
#   <plado.pddl.action.Action at 0x78420335ccd0>,
#   <plado.pddl.action.Action at 0x78420335d090>,
#   <plado.pddl.action.Action at 0x784203354fc0>),
#  'derived_predicates': ()}
