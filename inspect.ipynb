# %%
import plado
from plado.parser import parse, parse_and_normalize
domain, problem = parse("data/stochastic/yahtzee/domain.pddl", "data/stochastic/yahtzee/1.pddl")
#domain, problem = parse("data/deterministic/blocksworld/domain.pddl", "data/deterministic/blocksworld/1.pddl")
# alternatively, with performing additional normalization steps
# domain, problem = parse_and_normalize(PATH_TO_DOMAIN, PATH_TO_PROBLEM)

# %%
domain.__dict__
# Out:
# {'name': 'yahtzee-single-reroll-single-shot',
#  'requirements': [':probabilistic-effects', ':conditional-effects'],
#  'types': (),
#  'constants': (),
#  'predicates': (<plado.pddl.boolean_expression.Predicate at 0x23161d38710>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cd4410>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cd40b0>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cd5610>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cd4230>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cd5910>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cd45f0>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cd42f0>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cd43b0>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cd4650>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cd48f0>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cd4770>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cd4830>,
#   <plado.pddl.boolean_expression.Predicate at 0x231674dc710>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cba450>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cbbcb0>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cb9a90>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cb9d30>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cb9e50>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cba8d0>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cba930>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cba750>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cbae10>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cbae70>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cbab70>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cbabd0>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cbb110>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cbadb0>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cbb050>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cbaff0>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cbb170>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cbb0b0>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cbb1d0>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cbb230>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cbb2f0>,
#   <plado.pddl.boolean_expression.Predicate at 0x23161cbb350>),
#  'functions': (),
#  'actions': (<plado.pddl.action.Action at 0x2316985be30>,
#   <plado.pddl.action.Action at 0x23169860320>,
#   <plado.pddl.action.Action at 0x23169443230>,
#   <plado.pddl.action.Action at 0x23169798910>,
#   <plado.pddl.action.Action at 0x23169593860>,
#   <plado.pddl.action.Action at 0x231696774d0>,
#   <plado.pddl.action.Action at 0x23169676990>,
#   <plado.pddl.action.Action at 0x23167425860>,
#   <plado.pddl.action.Action at 0x231674245d0>,
#   <plado.pddl.action.Action at 0x23161d559f0>,
#   <plado.pddl.action.Action at 0x23161d55ef0>),
#  'derived_predicates': ()}
